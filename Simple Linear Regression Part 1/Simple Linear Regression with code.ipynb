# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Placements_data=pd.read_csv('placement.csv')

# %%
Placements_data.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(Placements_data['cgpa'],Placements_data['package'])
plt.xlabel("CGPA")
plt.ylabel("Package")
# Out:
# Text(0, 0.5, 'Package')

# %%
X = Placements_data.iloc[:,0:1]
# :    → select all rows
# 0:1  → select column at index 0 (first column)
# Using 0:1 instead of 0 keeps the result as a DataFrame (2D), which sklearn expects

y = Placements_data.iloc[:,-1]
# :   → select all rows
# -1  → select the last column of the dataset
# This column usually represents the output we want to predict (e.g., Salary or Placement)

# %%
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %% [raw]
# from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      cgpa
# 95   6.63
# 15   7.25
# 30   7.36
# 158  5.95
# 128  7.93
# 115  8.35
# 69   7.30
# 170  6.22
# 174  7.32
# 45   7.87
# 66   5.11
# 182  5.88
# 165  8.21
# 78   6.59
# 186  7.84
# 177  7.09
# 56   5.84
# 152  7.37
# 82   5.58
# 68   7.56
# 124  6.06
# 16   6.84
# 148  7.57
# 93   6.79
# 65   7.60
# 60   5.61
# 84   4.26
# 67   6.51
# 125  7.33
# 132  5.84
# 9    8.31
# 18   6.94
# 55   8.20
# 75   6.97
# 150  6.30
# 104  7.62
# 135  6.10
# 137  7.14
# 164  9.06
# 76   6.94
# 79   7.18
# 197  7.21
# 38   8.62
# 24   6.53
# 122  5.12
# 195  6.93
# 29   7.15
# 19   7.48
# 143  4.85
# 86   7.61
# 114  5.84
# 173  6.75
# 5    7.89
# 126  5.91
# 117  7.12
# 73   8.44
# 140  7.91
# 98   7.69
# 172  6.93
# 96   7.11

# %%
y_test
# Out:
# 95     2.79
# 15     3.23
# 30     3.26
# 158    3.04
# 128    3.34
# 115    4.21
# 69     2.94
# 170    2.87
# 174    2.99
# 45     3.58
# 66     1.63
# 182    2.08
# 165    4.08
# 78     2.21
# 186    3.47
# 177    3.64
# 56     2.74
# 152    3.08
# 82     2.17
# 68     2.99
# 124    2.31
# 16     2.35
# 148    3.40
# 93     3.08
# 65     3.81
# 60     2.19
# 84     1.53
# 67     2.89
# 125    3.16
# 132    2.48
# 9      3.51
# 18     2.98
# 55     3.39
# 75     3.28
# 150    2.73
# 104    3.74
# 135    2.60
# 137    3.13
# 164    3.82
# 76     3.15
# 79     3.00
# 197    3.24
# 38     4.36
# 24     2.71
# 122    2.01
# 195    2.46
# 29     3.49
# 19     2.83
# 143    1.54
# 86     2.77
# 114    1.87
# 173    2.56
# 5      2.99
# 126    2.60
# 117    2.99
# 73     4.03
# 140    3.15
# 98     3.83
# 172    2.51
# 96     2.61
# Name: package, dtype: float64

# %%
lr.predict(X_test.iloc[[5.91]])  #double brackets [[0]] This keeps the data as a DataFrame not as numpy array
# Out:
# array([3.78012708])

# %%
plt.scatter(Placements_data['cgpa'],Placements_data["package"])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel("CGPA")
plt.ylabel("package")
# Out:
# Text(0, 0.5, 'package')

# %%
m=lr.coef_
b=lr.intercept_

#y=mx+b

# %%
y1=(m*8.52)+b
y1
# Out:
# array([3.87705784])

# %%
y2=(m*8.52)+b
y2
# Out:
# array([3.87705784])

# %%
y3=(m*8.52)+b
y3
# Out:
# array([3.87705784])
