# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
arr1=np.array(45)

# %%
print(arr1)
# Out:
# 45

# %%
arr2=np.array([[45,78,23,45],[45,78,32,65]])

# %%
print(arr2)
# Out:
# [[45 78 23 45]
#  [45 78 32 65]]

# %%
print(arr2.shape)
# Out:
# (2, 4)

# %%
print(arr2.size)
# Out:
# 8

# %%
print(arr2.dtype)
# Out:
# int64

# %%
a = np.array([1, 2, 3]) 
b = np.array([4, 5, 6])

# %%
print(a+b)
print(a-b)
print(a*b)
print(np.dot(a, b))
# Out:
# [5 7 9]
# [-3 -3 -3]
# [ 4 10 18]
# 32

# %%
arr = np.arange(1, 10)

# %%
print(arr.reshape(3, 3))
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
arr = np.array([10, 20, 30, 40])

# %%
print(np.sum(arr)) 
print(np.mean(arr))
print(np.std(arr))  
print(np.max(arr))
print(np.min(arr))
# Out:
# 100
# 25.0
# 11.180339887498949
# 40
# 10

# %%
print(np.random.rand(3, 3))
# Out:
# [[0.57406801 0.73147171 0.0420007 ]
#  [0.99066678 0.18720993 0.90275522]
#  [0.24574254 0.50749318 0.43312307]]

# %%
print(np.random.randint(1, 100, (3, 3)) )
# Out:
# [[90 89 52]
#  [49  4 88]
#  [34  3 73]]

# %%
arr = np.array([10, 20, 30, 40])
print(arr[0])  
print(arr[-1])
# Out:
# 10
# 40

# %%
arr = np.array([10, 20, 30, 40, 50])

print(arr[1:4])  
print(arr[:3])  
print(arr[::2])
# Out:
# [20 30 40]
# [10 20 30]
# [10 30 50]

# %%
arr = np.array([1.5, 2.7, 3.9])
print(arr.dtype)  # Output: float64

arr_int = arr.astype(np.int32)
print(arr_int)   
print(arr_int.dtype)
# Out:
# float64
# [1 2 3]
# int32

# %%
arr = np.array(['apple', 'banana', 'cherry'], dtype='U10') 
print(arr)
# Out:
# ['apple' 'banana' 'cherry']

# %%
arr = np.array([{'a': 1}, [1, 2, 3], 'hello'], dtype=object)
print(arr)
# Out:
# [{'a': 1} list([1, 2, 3]) 'hello']
